# %%
import pandas as pd

test =   {'Cherry Picking'               :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/Cherry%20Picking.tsv',       
        'Evading the Burden of Proof'   :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/Evading%20the%20Burden%20of%20Proof.tsv',
        'False Analogy'                 :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/False%20Analogy.tsv',
        'False Authority'               :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/False%20Authority.tsv',
        'False Cause'                   :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/False%20Cause.tsv',
        'Hasty Generalization'          :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/Hasty%20Generalization.tsv',
        'No Fallacy'                    :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/No%20Fallacy.tsv',
        'Post Hoc'                      :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/Post%20Hoc.tsv',
        'Red Herring'                   :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/Red%20Herring.tsv',
        'Strawman'                      :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/Strawman.tsv',
        'Vagueness'                     :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/test/Vagueness.tsv'}

train = {'Cherry Picking'               :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/Cherry%20Picking.tsv',       
        'Evading the Burden of Proof'   :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/Evading%20the%20Burden%20of%20Proof.tsv',
        'False Analogy'                 :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/False%20Analogy.tsv',
        'False Authority'               :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/False%20Authority.tsv',
        'False Cause'                   :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/False%20Cause.tsv',
        'Hasty Generalization'          :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/Hasty%20Generalization.tsv',
        'No Fallacy'                    :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/No%20Fallacy.tsv',
        'Post Hoc'                      :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/Post%20Hoc.tsv',
        'Red Herring'                   :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/Red%20Herring.tsv',
        'Strawman'                      :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/Strawman.tsv',
        'Vagueness'                     :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/train/Vagueness.tsv'}

dev =   {'Cherry Picking'               :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/Cherry%20Picking.tsv',       
        'Evading the Burden of Proof'   :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/Evading%20the%20Burden%20of%20Proof.tsv',
        'False Analogy'                 :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/False%20Analogy.tsv',
        'False Authority'               :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/False%20Authority.tsv',
        'False Cause'                   :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/False%20Cause.tsv',
        'Hasty Generalization'          :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/Hasty%20Generalization.tsv',
        'No Fallacy'                    :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/No%20Fallacy.tsv',
        'Post Hoc'                      :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/Post%20Hoc.tsv',
        'Red Herring'                   :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/Red%20Herring.tsv',
        'Strawman'                      :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/Strawman.tsv',
        'Vagueness'                     :'https://raw.githubusercontent.com/Tariq60/fallacy-detection/master/data/climate/dev/Vagueness.tsv'}


urls = [dev, train, test]


df = pd.DataFrame()

for s, split in zip(['dev', 'train', 'test'], urls):
    for label, url in split.items():
        print(s, label)
        try:
                aux = pd.read_csv(url, sep='\t')
                aux['split'] = s
                aux['label'] = label.lower()

                df = pd.concat([df, aux], ignore_index=True)
        except:
                aux = pd.read_csv(label+'.tsv', sep='\t')
                aux['split'] = s
                aux['label'] = label.lower()

                df = pd.concat([df, aux], ignore_index=True)


# Dataset download train vagueness has an error, so I had to manually change an accent in line 36 to properly read the file.
# Out:
# dev Cherry Picking
# dev Evading the Burden of Proof
# dev False Analogy
# dev False Authority
# dev False Cause
# dev Hasty Generalization
# dev No Fallacy
# dev Post Hoc
# dev Red Herring
# dev Strawman
# dev Vagueness
# train Cherry Picking
# train Evading the Burden of Proof
# train False Analogy
# train False Authority
# train False Cause
# train Hasty Generalization
# train No Fallacy
# train Post Hoc
# train Red Herring
# train Strawman
# train Vagueness
# test Cherry Picking
# test Evading the Burden of Proof
# test False Analogy
# test False Authority
# test False Cause
# test Hasty Generalization
# test No Fallacy
# test Post Hoc
# test Red Herring
# test Strawman
# test Vagueness

# %%
df[df.isna().any(axis=1)]
# Out:
#     fact_checked_segment                            comment_by_fact-checker  \
# 73                   NaN                                                NaN
# 330                  NaN  This is only true if you selectively pick stud...
#
#      split       label
# 73     dev  no fallacy
# 330  train  no fallacy

# %%
df.to_csv('climatedataset2.csv', index=False, encoding='utf-8')

# %%
df
# Out:
#                                   fact_checked_segment  \
# 0    “The study is the product of a large group of ...
# 1    “there are alarming stories every day, like la...
# 2    “The report confidently claims that when tempe...
# 3    “In recent decades this warming has been accom...
# 4    “According to a recent National Economic Resea...
# ..                                                 ...
# 680  “a constant swarm of out-of-control typhoons a...
# 681  the first scientists to show that the thick ic...
# 682  “and we will need to have invented technologie...
# 683  “Recent computer forecasts suggest that if gre...
# 684  data] show only slight warming, mostly at nigh...
#
#                                comment_by_fact-checker split           label
# 0    This sounds like there are only 24 data points...   dev  cherry picking
# 1    I would like to add that this “twice as fast” ...   dev  cherry picking
# ...
